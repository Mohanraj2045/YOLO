# %% [markdown]
# Mounting the Googledrive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Install ultralytics for YOLO

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# Getting YOLO model

# %%
model = YOLO("yolov8s.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
# ...

# %% [markdown]
# Training The Model By costum data usin YALM file

# %%
model.train(data = r"/content/drive/MyDrive/Deer/config.yaml",epochs = 100)
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Exporting weight as model

# %%
predict = YOLO("/content/runs/detect/train/weights/best.pt")

# %% [markdown]
# Making prediction on the video

# %%
predict("/content/drive/MyDrive/Deer/gettyimages-700-96-640_adpp.mp4",save = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/300) /content/drive/MyDrive/Deer/gettyimages-700-96-640_adpp.mp4: 384x640 1 deer, 126.0ms
# video 1/1 (2/300) /content/drive/MyDrive/Deer/gettyimages-700-96-640_adpp.mp4: 384x640 1 deer, 12.6ms
# video 1/1 (3/300) /content/drive/MyDrive/Deer/gettyimages-700-96-640_adpp.mp4: 384x640 1 deer, 13.5ms
# video 1/1 (4/300) /content/drive/MyDrive/Deer/gettyimages-700-96-640_adpp.mp4: 384x640 1 deer, 15.4ms
# ...

# %% [markdown]
# Predicted video is savad in "//content/drive/MyDrive/Deer/gettyimages-700-96-640_adpp.mp4"
